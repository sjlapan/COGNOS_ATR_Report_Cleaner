# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('ATR Daily Report_1-1-19_to_1-3-21.csv')
df.head()
# Out:
#    Date Time Start Short   Road                                Device  \
# 0  01/01/2019  (Tuesday)  I 225  225N011 SH 225 S/O I-70 - N/O COLFAX
# 1  01/01/2019  (Tuesday)  I 225  225N011 SH 225 S/O I-70 - N/O COLFAX
# 2  01/01/2019  (Tuesday)  I 225  225N011 SH 225 S/O I-70 - N/O COLFAX
# 3  01/01/2019  (Tuesday)  I 225  225N011 SH 225 S/O I-70 - N/O COLFAX
# 4  01/01/2019  (Tuesday)  I 225  225N011 SH 225 S/O I-70 - N/O COLFAX
#
#   Data Source  Site ID           Hour Lane Direction  Lane # Car Volume  \
# 0   MS2 Count   105029  00:00 - 01:00          North       1        NaN
# 1   MS2 Count   105029  00:00 - 01:00          North       2        NaN
# 2   MS2 Count   105029  00:00 - 01:00          North       3        NaN
# 3   MS2 Count   105029  00:00 - 01:00          South       1        NaN
# 4   MS2 Count   105029  00:00 - 01:00          South       2        NaN
#
#   Truck Volume  ... Total(Unknown Count) Total(Total) Total(Car Count).1  \
# ...
